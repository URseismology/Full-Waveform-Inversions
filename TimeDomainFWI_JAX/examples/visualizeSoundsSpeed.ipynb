# %%
import jax.numpy as jnp
import numpy as np
from PIL import Image
from jax import jit
import matplotlib.pyplot as plt
from interpax import interp2d
from utils.getSoundSpeed import soundSpeedPhantom2D

# %% [markdown]
# ### Set Parameters

# %%
# parameters
dx = 1.5e-3
dy = dx
xmax = 141e-3

# create 1D grids
x = jnp.arange(-xmax, xmax + dx, dx)
y = x

# sizes
Nx = x.size
Ny = y.size

# 2D meshgrid (MATLAB‐style)
X, Y = jnp.meshgrid(x, y, indexing='xy')
# Out:
# An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.

# %% [markdown]
# ### Load Image File

# %%
img_path = 'data/breast_ct.jpg'
C, c_bkgnd = soundSpeedPhantom2D(X, Y, img_path)

# %% [markdown]
# ### Visualize

# %%
plt.figure(figsize=(4,4))
#plt.pcolormesh(x,np.flip(y),C.T, cmap='viridis')
plt.imshow(C, cmap='viridis')
plt.axis('off')
plt.show()
